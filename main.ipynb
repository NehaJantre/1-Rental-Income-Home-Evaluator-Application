# %%
# Import the required libraries and dependencies
import os
import pandas as pd
import plotly.express as px
from pathlib import Path
from dotenv import load_dotenv
import hvplot.pandas

# %%
# create airbnb_listingdata dataframe
airbnb_listingdata_df =  pd.read_csv(
    Path("Data/listings.csv")
)

# Review the first and last five rows of the DataFrame
display(airbnb_listingdata_df.head())
display(airbnb_listingdata_df.tail())
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
# filter airbnb_listingdata_df columns
columns = [ "id", "neighbourhood",  "zipcode", "latitude", "longitude", "property_type", "room_type", "bedrooms", "bathrooms","price"]
airbnb_listingdata_df = airbnb_listingdata_df[columns]
display(airbnb_listingdata_df.head())
display(airbnb_listingdata_df.tail())
# Out:
#         id neighbourhood zipcode   latitude   longitude property_type  \
# 0   241032    Queen Anne   98119  47.636289 -122.371025     Apartment
# 1   953595    Queen Anne   98119  47.639123 -122.365666     Apartment
# 2  3308979    Queen Anne   98119  47.629724 -122.369483         House
# 3  7421966    Queen Anne   98119  47.638473 -122.369279     Apartment
# 4   278830    Queen Anne   98119  47.632918 -122.372471         House
#
#          room_type  bedrooms  bathrooms    price
# 0  Entire home/apt       1.0        1.0   $85.00
# 1  Entire home/apt       1.0        1.0  $150.00
# 2  Entire home/apt       5.0        4.5  $975.00
# 3  Entire home/apt       0.0        1.0  $100.00
# 4  Entire home/apt       3.0        2.0  $450.00
#             id neighbourhood zipcode   latitude   longitude property_type  \
# 3813   8101950       Fremont   98107  47.664295 -122.359170         House
# 3814   8902327   Portage Bay   98102  47.649552 -122.318309     Apartment
# ...

# %%
# select only rows with property_type as 'Apartment' or 'House'
options = ['Apartment', 'House']
airbnb_listingdata_df = airbnb_listingdata_df[airbnb_listingdata_df['property_type'].isin(options)]

display(airbnb_listingdata_df.head())
display(airbnb_listingdata_df.tail())
# Out:
#         id neighbourhood zipcode   latitude   longitude property_type  \
# 0   241032    Queen Anne   98119  47.636289 -122.371025     Apartment
# 1   953595    Queen Anne   98119  47.639123 -122.365666     Apartment
# 2  3308979    Queen Anne   98119  47.629724 -122.369483         House
# 3  7421966    Queen Anne   98119  47.638473 -122.369279     Apartment
# 4   278830    Queen Anne   98119  47.632918 -122.372471         House
#
#          room_type  bedrooms  bathrooms    price
# 0  Entire home/apt       1.0        1.0   $85.00
# 1  Entire home/apt       1.0        1.0  $150.00
# 2  Entire home/apt       5.0        4.5  $975.00
# 3  Entire home/apt       0.0        1.0  $100.00
# 4  Entire home/apt       3.0        2.0  $450.00
#             id neighbourhood zipcode   latitude   longitude property_type  \
# 3812   3383329       Fremont   98107  47.654516 -122.358124     Apartment
# 3813   8101950       Fremont   98107  47.664295 -122.359170         House
# ...

# %%
# remove invalid values

airbnb_listingdata_df = airbnb_listingdata_df.dropna()
display(airbnb_listingdata_df.head())
display(airbnb_listingdata_df.tail())
# Out:
#         id neighbourhood zipcode   latitude   longitude property_type  \
# 0   241032    Queen Anne   98119  47.636289 -122.371025     Apartment
# 1   953595    Queen Anne   98119  47.639123 -122.365666     Apartment
# 2  3308979    Queen Anne   98119  47.629724 -122.369483         House
# 3  7421966    Queen Anne   98119  47.638473 -122.369279     Apartment
# 4   278830    Queen Anne   98119  47.632918 -122.372471         House
#
#          room_type  bedrooms  bathrooms    price
# 0  Entire home/apt       1.0        1.0   $85.00
# 1  Entire home/apt       1.0        1.0  $150.00
# 2  Entire home/apt       5.0        4.5  $975.00
# 3  Entire home/apt       0.0        1.0  $100.00
# 4  Entire home/apt       3.0        2.0  $450.00
#             id neighbourhood zipcode   latitude   longitude property_type  \
# 3811   8578490       Fremont   98103  47.657898 -122.346692     Apartment
# 3812   3383329       Fremont   98107  47.654516 -122.358124     Apartment
# ...

# %%
# find duplicate values in airbnb_listingdata_df
airbnb_listingdata_df.duplicated().sum()
# Out:
# 0

# %%
# Use the dtypes function to check the data type of each column in the DataFrame
airbnb_listingdata_df.dtypes
# Out:
# id                 int64
# neighbourhood     object
# zipcode           object
# latitude         float64
# longitude        float64
# property_type     object
# room_type         object
# bedrooms         float64
# bathrooms        float64
# price             object
# dtype: object

# %%
# For all the rows in the "price", use the str.replace function 
# to replace the "$" with empty strings ("")
airbnb_listingdata_df.loc[:, "price"] = airbnb_listingdata_df.loc[:, "price"].str.replace("$", "")

# Call the head function to review the first 5 rows of the DataFrame
airbnb_listingdata_df.head()
# Out:
# C:\Users\zach_\anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
#         id neighbourhood zipcode   latitude   longitude property_type  \
# 0   241032    Queen Anne   98119  47.636289 -122.371025     Apartment
# 1   953595    Queen Anne   98119  47.639123 -122.365666     Apartment
# 2  3308979    Queen Anne   98119  47.629724 -122.369483         House
# 3  7421966    Queen Anne   98119  47.638473 -122.369279     Apartment
# 4   278830    Queen Anne   98119  47.632918 -122.372471         House
#
#          room_type  bedrooms  bathrooms   price
# 0  Entire home/apt       1.0        1.0   85.00
# 1  Entire home/apt       1.0        1.0  150.00
# ...

# %%
# For all the rows in the "price", use the str.replace function 
# to replace the "," with empty strings ("")
airbnb_listingdata_df.loc[:, "price"] = airbnb_listingdata_df.loc[:, "price"].str.replace(",", "")

# Call the head function to review the first 5 rows of the DataFrame
airbnb_listingdata_df.head()
# Out:
#         id neighbourhood zipcode   latitude   longitude property_type  \
# 0   241032    Queen Anne   98119  47.636289 -122.371025     Apartment
# 1   953595    Queen Anne   98119  47.639123 -122.365666     Apartment
# 2  3308979    Queen Anne   98119  47.629724 -122.369483         House
# 3  7421966    Queen Anne   98119  47.638473 -122.369279     Apartment
# 4   278830    Queen Anne   98119  47.632918 -122.372471         House
#
#          room_type  bedrooms  bathrooms   price
# 0  Entire home/apt       1.0        1.0   85.00
# 1  Entire home/apt       1.0        1.0  150.00
# 2  Entire home/apt       5.0        4.5  975.00
# 3  Entire home/apt       0.0        1.0  100.00
# 4  Entire home/apt       3.0        2.0  450.00

# %%
# For all the rows in "price", use the astype function 
# to change the data type from Object (string) to float
airbnb_listingdata_df["price"] = airbnb_listingdata_df["price"].astype(float)
# Call the dtypes function on the `airbnb_listingdata_df` DataFrame to confirm the update
airbnb_listingdata_df.dtypes
# Out:
# id                 int64
# neighbourhood     object
# zipcode           object
# latitude         float64
# longitude        float64
# property_type     object
# room_type         object
# bedrooms         float64
# bathrooms        float64
# price            float64
# dtype: object

# %%
# create airbnb_calendardata dataframe
airbnb_calendardata_df =  pd.read_csv(
    Path("Data/calendar.csv")
)

# Review the first and last five rows of the DataFrame
display(airbnb_calendardata_df.head())
display(airbnb_calendardata_df.tail())
# Out:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN
#          listing_id        date available price
# 1393565    10208623  2016-12-29         f   NaN
# 1393566    10208623  2016-12-30         f   NaN
# 1393567    10208623  2016-12-31         f   NaN
# 1393568    10208623  2017-01-01         f   NaN
# 1393569    10208623  2017-01-02         f   NaN

# %%
# remove invalid values

airbnb_calendardata_df = airbnb_calendardata_df.dropna()
display(airbnb_calendardata_df.head())
display(airbnb_calendardata_df.tail())
# Out:
#     listing_id        date available   price
# 0       241032  2016-01-04         t  $85.00
# 1       241032  2016-01-05         t  $85.00
# 9       241032  2016-01-13         t  $85.00
# 10      241032  2016-01-14         t  $85.00
# 14      241032  2016-01-18         t  $85.00
#          listing_id        date available   price
# 1393207    10208623  2016-01-06         t  $87.00
# 1393208    10208623  2016-01-07         t  $87.00
# 1393211    10208623  2016-01-10         t  $87.00
# 1393212    10208623  2016-01-11         t  $87.00
# 1393213    10208623  2016-01-12         t  $87.00

# %%
# find duplicate values in airbnb_calendardata_df
airbnb_calendardata_df.duplicated().sum()
# Out:
# 0

# %%
# Use the dtypes function to check the data type of each column in the DataFrame
airbnb_calendardata_df.dtypes
# Out:
# listing_id     int64
# date          object
# available     object
# price         object
# dtype: object

# %%
# For all the rows in the "price", use the str.replace function 
# to replace the "$" with empty strings ("")
airbnb_calendardata_df.loc[:, "price"] = airbnb_calendardata_df.loc[:, "price"].str.replace("$", "")

# Call the head function to review the first 5 rows of the DataFrame
airbnb_calendardata_df.head()
# Out:
# C:\Users\zach_\anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
#     listing_id        date available  price
# 0       241032  2016-01-04         t  85.00
# 1       241032  2016-01-05         t  85.00
# 9       241032  2016-01-13         t  85.00
# 10      241032  2016-01-14         t  85.00
# 14      241032  2016-01-18         t  85.00

# %%
# For all the rows in the "price", use the str.replace function 
# to replace the "," with empty strings ("")
airbnb_calendardata_df.loc[:, "price"] = airbnb_calendardata_df.loc[:, "price"].str.replace(",", "")

# Call the head function to review the first 5 rows of the DataFrame
airbnb_calendardata_df.head()
# Out:
#     listing_id        date available  price
# 0       241032  2016-01-04         t  85.00
# 1       241032  2016-01-05         t  85.00
# 9       241032  2016-01-13         t  85.00
# 10      241032  2016-01-14         t  85.00
# 14      241032  2016-01-18         t  85.00

# %%
# For all the rows in "price", use the astype function 
# to change the data type from Object (string) to float
airbnb_calendardata_df["price"] = airbnb_calendardata_df["price"].astype(float)
# Call the dtypes function on the `airbnb_calendardata_df` DataFrame to confirm the update
airbnb_calendardata_df.dtypes
# Out:
# listing_id      int64
# date           object
# available      object
# price         float64
# dtype: object

# %%
house_sales_df =  pd.read_csv(
    Path("Data/RDC_Inventory_Core_Metrics_Zip_History.csv")
)

display(house_sales_df.head())
# Out:
#       Date  Month    Year month_date_yyyymm postal_code     zip_name flag  \
# 0  2021-06    6.0  2021.0            202106       98104  seattle, wa  NaN
# 1  2021-06    6.0  2021.0            202106       98103  seattle, wa  NaN
# 2  2021-06    6.0  2021.0            202106       98109  seattle, wa  NaN
# 3  2021-06    6.0  2021.0            202106       98133  seattle, wa  NaN
# 4  2021-06    6.0  2021.0            202106       98101  seattle, wa  NaN
#
#    median_listing_price  median_listing_price_mm  median_listing_price_yy  \
# 0              709950.0                  -0.1125                   0.0456
# 1              719990.0                  -0.0204                   0.0512
# 2              702000.0                   0.0189                  -0.1588
# 3              621000.0                   0.0351                   0.0024
# 4              799999.0                   0.1269                   0.0895
#
#    ...  average_listing_price  average_listing_price_mm  \
# ...

# %%
# filter house_sales_df columns

columns = [ "postal_code", "median_listing_price",  "median_listing_price_per_square_foot", "median_square_feet", "average_listing_price", "Neighborhood", "Year"]
house_sales_df = house_sales_df[columns]
house_sales_df = house_sales_df.dropna()
display(house_sales_df.head())
display(house_sales_df.tail())
# Out:
#   postal_code  median_listing_price  median_listing_price_per_square_foot  \
# 0       98104              709950.0                            883.977224
# 1       98103              719990.0                            571.926469
# 2       98109              702000.0                            665.278934
# 3       98133              621000.0                            416.598804
# 4       98101              799999.0                            995.301359
#
#    median_square_feet  average_listing_price    Neighborhood    Year
# 0               906.0           1.503083e+06  Pioneer Square  2021.0
# 1              1199.5           8.418694e+05       Greenlake  2021.0
# 2              1048.5           1.098175e+06      Queen Anne  2021.0
# 3              1340.0           6.450834e+05       Northgate  2021.0
# 4               959.0           1.603608e+06        Downtown  2021.0
#      postal_code  median_listing_price  median_listing_price_per_square_foot  \
# ...

# %%
median_sales_price_seattle = (
    house_sales_df[['Year','median_listing_price_per_square_foot','median_listing_price','Neighborhood']]
    .groupby('Neighborhood')
    .mean()
)
median_sales_price_seattle.head(15)
# Out:
#                        Year  median_listing_price_per_square_foot  \
# Neighborhood
# Alki Beach      2019.317073                            490.169125
# Ballard         2019.367089                            472.858491
# Belltown        2019.317073                            707.028148
# Capital Hill    2019.285714                            657.712750
# Columbia City   2019.285714                            484.345195
# Downtown        2019.285714                            949.338077
# Federal Way     2016.000000                            602.237547
# Greenlake       2019.285714                            538.121596
# Laurelhurst     2019.301205                            456.247569
# Madrona         2019.285714                            541.989473
# Magnolia        2018.979167                            462.435491
# Mount Baker     2019.153846                            333.335470
# Northgate       2019.325153                            408.486002
# ...

# %%
median_sales_price_seattle.hvplot.bar(
     x='Neighborhood',
     y='median_listing_price',
     title="Median Listing Price By Neighborhood",
     rot=30 ).opts(yformatter='%.0f',ylim=(360000, 1400000))
# Out:
# :Bars   [Neighborhood]   (median_listing_price)

# %%
prices_by_year_by_neighborhood = house_sales_df.groupby(['Year', 'Neighborhood']).mean()

prices_by_year_by_neighborhood.head()
# Out:
#                      median_listing_price  \
# Year   Neighborhood
# 2016.0 Federal Way              1694000.0
#        Magnolia                  479950.0
#        Mount Baker               550000.0
# 2017.0 Magnolia                  290200.0
#        Renton                    829950.0
#
#                      median_listing_price_per_square_foot  median_square_feet  \
# Year   Neighborhood
# 2016.0 Federal Way                             602.237547              2840.0
#        Magnolia                                181.602843              2706.0
#        Mount Baker                             275.862069              2200.0
# 2017.0 Magnolia                                169.250191              1793.9
#        Renton                                  308.584442              2995.0
#
#                      average_listing_price
# Year   Neighborhood
# 2016.0 Federal Way            2.444152e+06
#        Magnolia               5.912186e+05
#        Mount Baker            7.749356e+05
# ...

# %%
price_per_sq_foot= house_sales_df.hvplot(
    x='Year',
    y=['median_listing_price_per_square_foot','median_listing_price'],
    groupby='Neighborhood',
    title = "Seattle Median House Sale Prices by Neighborhood",
    legend="top_left"
)

price_per_sq_foot
# Out:
# :DynamicMap   [Neighborhood]
#    :NdOverlay   [Variable]
#       :Curve   [Year]   (value)

# %%
### Zach (ZZ) since sqft column is unuseable change KPI to: (Airbnb nighly $ rate / avg bedrooms) / the avg $ per sqft from the  RDC_Inventory_Core_Metrics.csv file

# filter columns in airbnb for zipcode, bedrooms, price
airbnb_col_filter = airbnb_listingdata_df.loc[:,["zipcode","bedrooms","price"]]

# groupby zipcode 
airbnb_prices_by_zip_and_beds = airbnb_col_filter.groupby(["zipcode"]).mean()

# %%
# (ZZ) average airbnb bedroom price by zipcode                                                          
avg_airbnb_bedroom_price_per_night_by_zipcode = airbnb_prices_by_zip_and_beds["price"] / airbnb_prices_by_zip_and_beds["bedrooms"]

# example df.columns = ['a', 'b']
avg_airbnb_bedroom_price_per_night_by_zipcode.columns = ["avg bedroom rate per night"]
avg_airbnb_bedroom_price_per_night_by_zipcode.sort_values()
# Out:
# zipcode
# 98178     53.571429
# 98108     57.744681
# 98177     58.933333
# 98133     63.860000
# 98106     66.423729
# 98125     69.648649
# 98118     69.860335
# 98144     76.068966
# 98117     81.288770
# 98115     81.316038
# 98105     84.035156
# 98103     84.622363
# 98136     84.825397
# 98126     85.152778
# 98116     90.626984
# 98107     91.296804
# 98199     99.621951
# 98122    101.048352
# 98112    102.379518
# 98146    108.500000
# 98102    113.808307
# 98119    114.317919
# 98109    119.747423
# 98104    140.283582
# 98101    140.539683
# 98134    149.000000
# 98121    149.453988
# dtype: float64

# %%
# (ZZ) the avg $ per sqft by zip from the house_sales_df (file name = RDC_Inventory_Core_Metrics_Zip_History.csv)

# filter for postal_code and median_listing_price_per_square_foot
house_sales_col_filter_df = house_sales_df.loc[:, ["postal_code", "median_listing_price_per_square_foot"]]

# %%
# (ZZ) groupby postal_code
house_sales_avg_listing_price_per_sqft_by_zip = house_sales_col_filter_df.groupby(["postal_code"]).mean()
house_sales_avg_listing_price_per_sqft_by_zip.sort_values(["median_listing_price_per_square_foot"])
# Out:
#              median_listing_price_per_square_foot
# postal_code
# 99111                                   89.251374
# 99672                                  159.997323
# 98564                                  166.859122
# 98422                                  181.602843
# 98239                                  202.256301
# 98292                                  227.886833
# 98188                                  242.643326
# 98148                                  251.175135
# 98168                                  258.510343
# 98198                                  277.767633
# 98178                                  282.690136
# 98072                                  308.584442
# 98146                                  325.029085
# 98166                                  333.615250
# 98106                                  370.832533
# 98155                                  374.042964
# 98133                                  381.633460
# ...

# %%
# (ZZ) rename postal_code column to zipcode

# %%
# (ZZ) join together the two dfs on the zipcode from airbnb (avg_airbnb_bedroom_price_per_night_by_zipcode)

#df_merge_col = pd.merge(df_row, df3, on='id')
#merge_df = pd.merge(house_sales_col_filter_df, house_sales_avg_listing_price_per_sqft_by_zip on = "zipcode" )

#df_merge_difkey = pd.merge(df_row, df3, left_on='id', right_on='id')
#merge_df = pd.merge(house_sales_col_filter_df, house_sales_avg_listing_price_per_sqft_by_zip left_on= "zipcode", right_on = "postal_code" ) 
#merge_df

# inner join but does not account for the different column names
#df_inner = pd.merge(df1, df2, on='id', how='inner')

# letf join 
#df_left = pd.merge(df1, df2, on='id', how='left')
#df_left


#join on index
#df_index = pd.merge(df1, df2, right_index=True, left_index=True)

#df_index = pd.merge(avg_airbnb_bedroom_price_per_night_by_zipcode, house_sales_avg_listing_price_per_sqft_by_zip, right_index=True, left_index=True)
#df_index


# merge and convert the Series to a DataFrame with to_frame(). So (if joining on index):
merged_df = house_sales_avg_listing_price_per_sqft_by_zip.merge(avg_airbnb_bedroom_price_per_night_by_zipcode.to_frame(), left_index=True, right_index=True)

# rename index to zipcode
merged_df.index.name = "zipcode"
merged_df
# Out:
#        median_listing_price_per_square_foot           0
# 98101                            949.338077  140.539683
# 98102                            657.712750  113.808307
# 98103                            538.121596   84.622363
# 98104                            834.039950  140.283582
# 98105                            539.628913   84.035156
# 98106                            370.832533   66.423729
# 98107                            563.575220   91.296804
# 98108                            388.779571   57.744681
# 98109                            651.498471  119.747423
# 98112                            615.355565  102.379518
# 98115                            468.623382   81.316038
# 98116                            507.610949   90.626984
# 98117                            471.855209   81.288770
# 98118                            388.896026   69.860335
# 98119                            579.794364  114.317919
# 98121                            818.975426  149.453988
# ...

# %%
# (ZZ) 

merged_df

#rename the columns

#merged_df.rename(columns={"0":"NewName"})
#merged_df.set_axis("zipcode", "price_per_sqft", "airbnb_bedroom_price")
#merged_df
# Out:
#          median_listing_price_per_square_foot           0
# zipcode
# 98101                              949.338077  140.539683
# 98102                              657.712750  113.808307
# 98103                              538.121596   84.622363
# 98104                              834.039950  140.283582
# 98105                              539.628913   84.035156
# 98106                              370.832533   66.423729
# 98107                              563.575220   91.296804
# 98108                              388.779571   57.744681
# 98109                              651.498471  119.747423
# 98112                              615.355565  102.379518
# 98115                              468.623382   81.316038
# 98116                              507.610949   90.626984
# 98117                              471.855209   81.288770
# 98118                              388.896026   69.860335
# 98119                              579.794364  114.317919
# ...

# %%
# (ZZ) divide the avg sqft price by zip from (house_sales_avg_listing_price_per_sqft_by_zip) by the avg price of bedroom from airbnb (avg_airbnb_bedroom_price_per_night_by_zipcode)
ratio =  merged_df[0] / merged_df["median_listing_price_per_square_foot"]

ratio.index.name = "zipcode"
ratio.sort_values()
# Out:
# zipcode
# 98177    0.144144
# 98101    0.148040
# 98108    0.148528
# 98144    0.154192
# 98105    0.155728
# 98103    0.157255
# 98107    0.161996
# 98112    0.166375
# 98133    0.167333
# 98104    0.168198
# 98122    0.171418
# 98117    0.172275
# 98102    0.173036
# 98115    0.173521
# 98125    0.176029
# 98116    0.178536
# 98106    0.179121
# 98118    0.179638
# 98121    0.182489
# 98109    0.183803
# 98178    0.189506
# 98136    0.191532
# 98119    0.197170
# 98199    0.197653
# 98126    0.205382
# 98146    0.333816
# dtype: float64

# %%
# (ZZ) chart the zipcodes with the raitio of the avg smallets sqft cost by the largest avg room rent by zipcode
ratio.plot.barh(figsize = (15,10), title = "Avg. AIRBNB Bedroom Rate and per SQFT Cost Ratio by Zipcode")
# Out:
# <AxesSubplot:title={'center':'Avg. AIRBNB Bedroom Rate and per SQFT Cost Ratio by Zipcode'}>
